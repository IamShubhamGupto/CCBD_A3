# %%
import image_slicer
import cv2
import numpy as np

# %%
x= 400
tiles = image_slicer.slice(r"D:\SHUBHAM\CCBD\S2A_MSIL2A_20190104T051211_N0211_R019_T43PGQ_20190104T094623_RGB.tif",x,save = False)
# Out:
# C:\ProgramData\Anaconda31\lib\site-packages\PIL\Image.py:2371: DecompressionBombWarning: Image size (120560400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning)

# %%
'''
#for GT image - sharpen
for tile in tiles:
    #Create the identity filter, but with the 1 shifted to the right!
    kernel = np.zeros( (7,7), np.float32)
    kernel[4,4] = 2.0   #Identity, times two! 

    #Create a box filter:
    boxFilter = np.ones( (7,7), np.float32) / 49.0

    #Subtract the two:
    kernel = kernel - boxFilter


    #Note that we are subject to overflow and underflow here...but I believe that
    # filter2D clips top and bottom ranges on the output, plus you'd need a
    # very bright or very dark pixel surrounded by the opposite type.

    tile = cv2.filter2D(np.float32(tile.image), -1, kernel)
'''
# Out:
# "\n#for GT image - sharpen\nfor tile in tiles:\n    #Create the identity filter, but with the 1 shifted to the right!\n    kernel = np.zeros( (7,7), np.float32)\n    kernel[4,4] = 2.0   #Identity, times two! \n\n    #Create a box filter:\n    boxFilter = np.ones( (7,7), np.float32) / 49.0\n\n    #Subtract the two:\n    kernel = kernel - boxFilter\n\n\n    #Note that we are subject to overflow and underflow here...but I believe that\n    # filter2D clips top and bottom ranges on the output, plus you'd need a\n    # very bright or very dark pixel surrounded by the opposite type.\n\n    tile = cv2.filter2D(np.float32(tile.image), -1, kernel)\n"

# %%
image_slicer.save_tiles(tiles, directory=r"D:\SHUBHAM\CCBD\tiles2",prefix='blr', format='tiff')
# Out:
# (<Tile #1 - blr_01_01.tiff>,
#  <Tile #2 - blr_01_02.tiff>,
#  <Tile #3 - blr_01_03.tiff>,
#  <Tile #4 - blr_01_04.tiff>,
#  <Tile #5 - blr_01_05.tiff>,
#  <Tile #6 - blr_01_06.tiff>,
#  <Tile #7 - blr_01_07.tiff>,
#  <Tile #8 - blr_01_08.tiff>,
#  <Tile #9 - blr_01_09.tiff>,
#  <Tile #10 - blr_01_10.tiff>,
#  <Tile #11 - blr_01_11.tiff>,
#  <Tile #12 - blr_01_12.tiff>,
#  <Tile #13 - blr_01_13.tiff>,
#  <Tile #14 - blr_01_14.tiff>,
#  <Tile #15 - blr_01_15.tiff>,
#  <Tile #16 - blr_01_16.tiff>,
#  <Tile #17 - blr_01_17.tiff>,
#  <Tile #18 - blr_01_18.tiff>,
#  <Tile #19 - blr_01_19.tiff>,
#  <Tile #20 - blr_01_20.tiff>,
#  <Tile #21 - blr_02_01.tiff>,
#  <Tile #22 - blr_02_02.tiff>,
#  <Tile #23 - blr_02_03.tiff>,
#  <Tile #24 - blr_02_04.tiff>,
#  <Tile #25 - blr_02_05.tiff>,
#  <Tile #26 - blr_02_06.tiff>,
#  <Tile #27 - blr_02_07.tiff>,
#  <Tile #28 - blr_02_08.tiff>,
#  <Tile #29 - blr_02_09.tiff>,
#  <Tile #30 - blr_02_10.tiff>,
#  <Tile #31 - blr_02_11.tiff>,
# ...
